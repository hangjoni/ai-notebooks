# %% [markdown]
# <a href="https://colab.research.google.com/github/hangjoni/ai-notebooks/blob/main/WWF_1_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 6 - Object Detection

# %% [markdown]
# ## Lesson Video:

# %%
#hide_input
from IPython.lib.display import YouTubeVideo
from datetime import timedelta
start = int(timedelta(minutes=34, seconds=27).total_seconds())
YouTubeVideo('5bSVug1YB3s', start=start)

# %%
#hide
#Run once per session
# !pip install fastai==2.1.10 fastcore==1.3.13 wwf==0.0.8 -q --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.9/52.9 KB 6.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastdownload 0.0.7 requires fastcore>=1.3.26, but you have fastcore 1.3.13 which is incompatible.

# %%
#hide_input
from wwf.utils import state_versions
state_versions(['fastai', 'fastcore', 'wwf'])
# Out:
# ---
# This article is also a Jupyter Notebook available to be run from the top down. There
# will be code snippets that you can then run in any environment.
#
# Below are the versions of `fastai`, `fastcore`, and `wwf` currently running at the time of writing this:
# * `fastai` : 2.1.10
# * `fastcore` : 1.3.13
# * `wwf` : 0.0.8
# ---

# %% [markdown]
# ## Object Detection
#
# Finding the localized area in which an object presides from two points, the bottom left and top right
#
# ![](https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2018/06/maxresdefault.jpg)

# %%
from fastai.vision.all import *

# %%
path = untar_data(URLs.PASCAL_2007)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1637801984' class='' max='1637796771' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1637801984/1637796771 02:39&lt;00:00]
#     </div>

# %% [markdown]
# Now how do we get our labels? `fastai` has a `get_annotations` function that we can use to grab the image and their bounding box. The one-line documentation states:
# "Open a COCO style json in `fname` and returns the list of filenames (with mabye `prefix`) and labelled bounding boxes."

# %%
path.ls()
# Out:
# (#8) [Path('/root/.fastai/data/pascal_2007/valid.json'),Path('/root/.fastai/data/pascal_2007/test.json'),Path('/root/.fastai/data/pascal_2007/test.csv'),Path('/root/.fastai/data/pascal_2007/train'),Path('/root/.fastai/data/pascal_2007/test'),Path('/root/.fastai/data/pascal_2007/train.csv'),Path('/root/.fastai/data/pascal_2007/segmentation'),Path('/root/.fastai/data/pascal_2007/train.json')]

# %% [markdown]
# We'll want to read out of the `train.json`

# %%
imgs, lbl_bbox = get_annotations(path/'train.json')

# %%
imgs[0]
# Out:
# '000012.jpg'

# %%
lbl_bbox[0]
# Out:
# ([[155, 96, 351, 270]], ['car'])

# %% [markdown]
# Next, we want to be able to quickly look up a corresponding image to it's label. We'll use a dictionary

# %%
img2bbox = dict(zip(imgs, lbl_bbox))

# %% [markdown]
# Let's check the first item

# %%
first = {k: img2bbox[k] for k in list(img2bbox)[:1]}; first
# Out:
# {'000012.jpg': ([[155, 96, 351, 270]], ['car'])}

# %% [markdown]
# Great! Now let's build our `DataBlock`. We'll have two outputs, the bounding box itself and a label, with one input.

# %%
getters = [lambda o: path/'train'/o, lambda o: img2bbox[o][0], lambda o: img2bbox[o][1]]

# %% [markdown]
# For our transforms, we'll use some of the ones we defined earlier

# %%
item_tfms = [Resize(128, method='pad'),]
batch_tfms = [Rotate(), Flip(), Dihedral(), Normalize.from_stats(*imagenet_stats)]

# %% [markdown]
# Why do we need a custom `get_images`? Because we want our **images** that came back to us, not the entire folder

# %% [markdown]
# TODO: Why does `imgs` work here? It was never defined

# %%
def get_train_imgs(noop):  return imgs

# %% [markdown]
# We'll now make our `DataBlock`. We want to adjust `n_inp` as we expect two outputs

# %%
pascal = DataBlock(blocks=(ImageBlock, BBoxBlock, BBoxLblBlock),
                 splitter=RandomSplitter(),
                 get_items=get_train_imgs,
                 getters=getters,
                 item_tfms=item_tfms,
                 batch_tfms=batch_tfms,
                 n_inp=1)

# %%
dls = pascal.dataloaders(path/'train')

# %%
dls.c = 20

# %%
dls.show_batch()

# %% [markdown]
# # The Model
#
# The architecture we are going to use is called `RetinaNet`. I've exported this all myself for you guys to use quickly, if you want to explore what's going on in the code I'd recommend the Object Detection lesson [here](https://www.youtube.com/watch?v=Z0ssNAbe81M&t=4496s)

# %% [markdown]
# Let's import it:

# %%
from wwf.vision.object_detection import *

# %% [markdown]
# We're still going to use transfer learning here by creating an `encoder` (body) of our model and a head

# %%
encoder = create_body(resnet34(), pretrained=True)

# %% [markdown]
# Now that we have our encoder, we can call the `RetinaNet` architecture. We'll pass in the encoder, the number of classes, and what we want our final bias to be on the last convolutional layer (how we initialize our model). Jeremy has his example at -4 so let's use this

# %%
get_c(dls)
# Out:
# 20

# %%
arch = RetinaNet(encoder, get_c(dls), final_bias=-4)

# %% [markdown]
# Another big difference is the head of our model. Instead of our linear layers with pooling layers:

# %%
create_head(124, 4)
# Out:
# Sequential(
#   (0): AdaptiveConcatPool2d(
#     (ap): AdaptiveAvgPool2d(output_size=1)
#     (mp): AdaptiveMaxPool2d(output_size=1)
#   )
#   (1): fastai.layers.Flatten(full=False)
#   (2): BatchNorm1d(248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): Dropout(p=0.25, inplace=False)
#   (4): Linear(in_features=248, out_features=512, bias=False)
#   (5): ReLU(inplace=True)
#   (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Linear(in_features=512, out_features=4, bias=False)
# )

# %% [markdown]
# We have one with a smoother, a classifer, and a `box_regressor` (to get our points)

# %%
arch.smoothers
# Out:
# ModuleList(
#   (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
arch.classifier
# Out:
# Sequential(
#   (0): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (1): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (2): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (3): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (4): Conv2d(256, 180, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
arch.box_regressor
# Out:
# Sequential(
#   (0): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (1): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (2): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (3): ConvLayer(
#     (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (4): Conv2d(256, 36, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# ## Loss Function
# Now we can move onto our loss function. For RetinaNet to work, we need to define what the aspect ratio's and scales of our image should be. The paper used [1,2**(1/3), 2**(2/3)], but they also used an image size of 600 pixels, so even the largest feature map (box) gave anchors that covered less than the image. But for us it would go over. As such we will use -1/3 and -2/3 instead. We will need these for inference later!

# %%
ratios = [1/2,1,2]
scales = [1,2**(-1/3), 2**(-2/3)]

# %% [markdown]
# Let's make our loss function, which is `RetinaNetFocalLoss`

# %%
crit = RetinaNetFocalLoss(scales=scales, ratios=ratios)

# %% [markdown]
# Now let's make our `Learner`!

# %% [markdown]
# We want to freeze our `encoder` and keep everything else unfrozen to start

# %%
def _retinanet_split(m): return L(m.encoder,nn.Sequential(m.c5top6, m.p6top7, m.merges, m.smoothers, m.classifier, m.box_regressor)).map(params)

# %%
learn = Learner(dls, arch, loss_func=crit, splitter=_retinanet_split)

# %%
learn.freeze()

# %% [markdown]
# Now let's train!

# %%
learn.fit_one_cycle(10, slice(1e-5, 1e-4))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='0' class='' max='31' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/31 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-47-5d23c3b5e06d> in <module>
# ----> 1 learn.fit_one_cycle(10, slice(1e-5, 1e-4))
#
# /usr/local/lib/python3.8/dist-packages/fastai/callback/schedule.py in fit_one_cycle(self, n_epoch, lr_max, div, div_final, pct_start, wd, moms, cbs, reset_opt, start_epoch)
#     117     keys = self.hps.keys() if keys is None else L(keys)
#     118     rows,cols = (len(keys)+1)//2, min(2, len(keys))
# --> 119     figsize = figsize or (6*cols,4*rows)
#     120     _, axs = plt.subplots(rows, cols, figsize=figsize)
#     121     axs = axs.flatten() if len(keys) > 1 else L(axs)
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in fit(self, n_epoch, lr, wd, cbs, reset_opt, start_epoch)
#     254         dec = self.dls.decode_batch(inp + tuplify(dec_preds))[0]
#     255         dec_inp,dec_targ = map(detuplify, [dec[:i],dec[i:]])
# --> 256         res = dec_targ,dec_preds[0],preds[0]
#     257         if with_input: res = (dec_inp,) + res
#     258         return res
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     191         self._do_epoch_train()
#     192         self._do_epoch_validate()
# --> 193
#     194     def _do_fit(self):
#     195         for epoch in range(self.n_epoch):
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in _do_fit(self)
#     243                 res[pred_i] = act(res[pred_i])
#     244                 if with_decoded: res.insert(pred_i+2, getattr(self.loss_func, 'decodes', noop)(res[pred_i]))
# --> 245             if reorder and hasattr(dl, 'get_idxs'): res = nested_reorder(res, tensor(idxs).argsort())
#     246             return tuple(res)
#     247         self._end_cleanup()
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     191         self._do_epoch_train()
#     192         self._do_epoch_validate()
# --> 193
#     194     def _do_fit(self):
#     195         for epoch in range(self.n_epoch):
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in _do_epoch(self)
#     237         with ContextManagers(ctx_mgrs):
#     238             self._do_epoch_validate(dl=dl)
# --> 239             if act is None: act = getattr(self.loss_func, 'activation', noop)
#     240             res = cb.all_tensors()
#     241             pred_i = 1 if with_input else 0
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in _do_epoch_train(self)
#     229             except TypeError as e:
#     230                 raise TypeError("`dl` is something other than a single `DataLoader` object")
# --> 231         if reorder and hasattr(dl, 'get_idxs'):
#     232             idxs = dl.get_idxs()
#     233             dl = dl.new(get_idxs = _ConstantFunc(idxs))
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     191         self._do_epoch_train()
#     192         self._do_epoch_validate()
# --> 193
#     194     def _do_fit(self):
#     195         for epoch in range(self.n_epoch):
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in all_batches(self)
#     197             self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#     198
# --> 199     def fit(self, n_epoch, lr=None, wd=None, cbs=None, reset_opt=False):
#     200         with self.added_cbs(cbs):
#     201             if reset_opt or not self.opt: self.create_opt()
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in one_batch(self, i, b)
#     225                   inner=False, reorder=True, cbs=None, **kwargs):
#     226         if dl is None: dl = self.dls[ds_idx].new(shuffled=False, drop_last=False)
# --> 227         else:
#     228             try: len(dl)
#     229             except TypeError as e:
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     191         self._do_epoch_train()
#     192         self._do_epoch_validate()
# --> 193
#     194     def _do_fit(self):
#     195         for epoch in range(self.n_epoch):
#
# /usr/local/lib/python3.8/dist-packages/fastai/learner.py in _do_one_batch(self)
#     206             self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     207
# --> 208     def _end_cleanup(self): self.dl,self.xb,self.yb,self.pred,self.loss = None,(None,),(None,),None,None
#     209     def __enter__(self): self(_before_epoch); return self
#     210     def __exit__(self, exc_type, exc_value, tb): self(_after_epoch)
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/wwf/vision/object_detection/metrics.py in forward(self, output, bbox_tgts, clas_tgts)
#     145         if self._change_anchors(sizes): self._create_anchors(sizes, clas_preds.device)
#     146         n_classes = clas_preds.size(2)
# --> 147         return sum([self._one_loss(cp, bp, ct, bt)
#     148                     for (cp, bp, ct, bt) in zip(clas_preds, bbox_preds, clas_tgts, bbox_tgts)])/clas_tgts.size(0)
#     149
#
# /usr/local/lib/python3.8/dist-packages/wwf/vision/object_detection/metrics.py in <listcomp>(.0)
#     145         if self._change_anchors(sizes): self._create_anchors(sizes, clas_preds.device)
#     146         n_classes = clas_preds.size(2)
# --> 147         return sum([self._one_loss(cp, bp, ct, bt)
#     148                     for (cp, bp, ct, bt) in zip(clas_preds, bbox_preds, clas_tgts, bbox_tgts)])/clas_tgts.size(0)
#     149
#
# /usr/local/lib/python3.8/dist-packages/wwf/vision/object_detection/metrics.py in _one_loss(self, clas_pred, bbox_pred, clas_tgt, bbox_tgt)
#     139         clas_tgt = torch.cat([clas_tgt.new_zeros(1).long(), clas_tgt])
#     140         clas_tgt = clas_tgt[matches[clas_mask]]
# --> 141         return bb_loss + self._focal_loss(clas_pred, clas_tgt)/torch.clamp(bbox_mask.sum(), min=1.)
#     142
#     143     def forward(self, output, bbox_tgts, clas_tgts):
#
# /usr/local/lib/python3.8/dist-packages/wwf/vision/object_detection/metrics.py in _focal_loss(self, clas_pred, clas_tgt)
#     116
#     117     def _focal_loss(self, clas_pred, clas_tgt):
# --> 118         encoded_tgt = encode_class(clas_tgt, clas_pred.size(1))
#     119         ps = torch.sigmoid(clas_pred.detach())
#     120         weights = encoded_tgt * (1-ps) + (1-encoded_tgt) * ps
#
# /usr/local/lib/python3.8/dist-packages/wwf/vision/object_detection/metrics.py in encode_class(idxs, n_classes)
#      28     mask = idxs != 0
#      29     i1s = LongTensor(list(range(len(idxs))))
# ---> 30     target[i1s[mask],idxs[mask]-1] = 1
#      31     return target
#      32
#
# RuntimeError: indices should be either on cpu or on the same device as the indexed tensor (cpu)

# %% [markdown]
# ## Word of Warning:
#
# `show_results` and `predict` both do not currently work. I'd recommend utilizing the [IceVision](https://github.com/airctic/icevision) library for your Object Detection needs.
